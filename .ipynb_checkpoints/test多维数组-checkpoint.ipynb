# %% [markdown]
# 多维数组及其子数组
# ====

# %%
import numpy as np

# %%
np.empty([4,4,2,2,5],dtype=np.int8)
# Out:
# array([[[[[  32,   32,   32,   32,   91],
#           [  49,   51,   48,   44,   32]],
#
#          [[  49,   51,   49,   44,   32],
#           [  49,   51,   50,   44,   32]]],
#
#
#         [[[  49,   51,   51,   44,   32],
#           [  49,   51,   52,   93,   93]],
#
#          [[  44,   92,  110,   92,  110],
#           [  32,   32,   32,   32,   32]]],
#
#
#         [[[  32,   32,   32,   32,   91],
#           [  91,   49,   51,   53,   44]],
#
#          [[  32,   49,   51,   54,   44],
#           [  32,   49,   51,   55,   44]]],
#
#
#         [[[  32,   49,   51,   56,   44],
#           [  32,   49,   51,   57,   93]],
#
#          [[  44,   92,  110,   32,   32],
#           [  32,   32,   32,   32,   32]]]],
#
#
#
#        [[[[  32,   32,   32,   91,   49],
#           [  52,   48,   44,   32,   49]],
#
#          [[  52,   49,   44,   32,   49],
#           [  52,   50,   44,   32,   49]]],
#
#
#         [[[  52,   51,   44,   32,   49],
# ...
